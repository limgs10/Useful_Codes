# %%
import pandas as pd

from snapgene_reader import snapgene_file_to_dict
from Bio import Seq
import os

file_path = "C:/Users/최민재/Useful_Codes/Cas9 crRNA Finder for Clean KO/ec_alkB.dna"
dictionary = snapgene_file_to_dict(file_path)

# PAM 주변의 crRNA sequence를 담을 1열짜리 빈 데이터프레임을 제작
target_df = pd.DataFrame(index = range(0,0),columns = ["target"])

# 전체 sequence 중 앞 500, 뒤 500 base를 제외한 gene of interest sequence를 따오기
gene_seq = dictionary['seq'][500:-499]

seq = Seq.Seq (gene_seq)
length = len(gene_seq)
gene_rev = str(seq.reverse_complement())


#reverse complement에서도 crRNA를 찾아야 하므로 gene_rev에 sequence를 저장

i=21
j=0

# 22번째 base부터 GG(PAM의 2,3번째 base)가 있는 위치를 찾고 그 앞 (1 base 떨어진) 20개의 base를 따와서 빈 데이터베이스에 저장
while i < length:
    PAM = gene_seq [i:i+2]
    if PAM == 'GG':
        target = gene_seq [i-21:i-1]
        target_df.loc[j,'target'] = target
        j = j+1
    i=i+1

#reverse complement에 대해 동일한 작업을 수행

i=21

while i < length:
    PAM = gene_rev [i:i+2]
    if PAM == 'GG':
        target = gene_rev [i-21:i-1]
        target_df.loc[j,'target'] = target
        j = j+1
    i=i+1

print (target_df)

#데이터베이스를 엑셀 파일로 저장

target_df.to_excel("C:/Users/최민재/Useful_Codes/Cas9 crRNA Finder for Clean KO/alkB_target_1.xlsx")
# Out:
# GC
# CT
# TG
# GA
# AA
# AC
# CC
# CG
# GT
# TG
# GG
# TGTTTGCCGATGCTGAACCG
# GC
# CA
# AA
# AG
# GA
# AG
# GC
# CC
# CA
# AC
# CT
# TG
# GG
# TGAACCGTGGCAAGAGCCAC
# GC
# CG
# GG
# ACCGTGGCAAGAGCCACTGG
# GC
# CT
# TG
# GG
# TGGCAAGAGCCACTGGCGGC
# GT
# TG
# GC
# CG
# GG
# AGAGCCACTGGCGGCTGGTG
# GT
# TA
# AA
# AT
# TT
# TT
# TT
# TA
# AC
# CG
# GG
# CGGCTGGTGCGGTAATTTTA
# GC
# CG
# GT
# TT
# TT
# TT
# TG
# GC
# CT
# TT
# TT
# TT
# TA
# AA
# AC
# CG
# GC
# CT
# TG
# GC
# CG
# GG
# GCGTTTTGCTTTTAACGCTG
# GA
# AG
# GC
# CA
# AA
# AC
# CT
# TG
# GA
# AT
# TC
# CC
# CG
# GC
# CG
# GA
# AT
# TA
# AT
# TT
# TA
# AA
# AT
# TG
# GA
# AC
# CG
# GT
# TT
# TG
# GC
# CC
# CA
# AG
# GC
# CC
# CA
# AG
# GT
# TC
# CG
# GC
# CC
# CG
# GT
# TT
# TT
# TC
# CG
# GC
# CC
# CA
# AG
# GA
# AT
# TG
# GG
# CCAGTCGCCGTTTCGCCAGA
# GT
# TC
# CA
# AC
# CC
# CC
# CC
# CC
# CG
# GG
# TTTCGCCAGATGGTCACCCC
# GG
# TTCGCCAGATGGTCACCCCC
# GG
# TCGCCAGATGGTCACCCCCG
# GG
# CGCCAGATGGTCACCCCCGG
# GA
# AT
# TA
# AT
# TA
# AC
# CC
# CA
# AT
# TG
# GT
# TC
# CG
# GG
# CCCCGGGGGATATACCATGT
# GT
# TG
# GG
# CGGGGGATATACCATGTCGG
# GC
# CG
# GA
# AT
# TG
# GA
# AC
# CC
# CA
# AA
# AC
# CT
# TG
# GT
# TG
# GG
# TCGGTGGCGATGACCAACTG
# GG
# CGGTGGCGATGACCAACTGT
# GC
# CA
# AT
# TC
# CT
# TG
# GG
# GATGACCAACTGTGGGCATC
# GG
# ATGACCAACTGTGGGCATCT
# GC
# CT
# TG
# GG
# CCAACTGTGGGCATCTGGGC
# GA
# AC
# CG
# GA
# AC
# CC
# CC
# CA
# AT
# TC
# CG
# GG
# ATCTGGGCTGGACGACCCAT
# GC
# CA
# AA
# AG
# GG
# GGCTGGACGACCCATCGGCA
# GT
# TT
# TA
# AT
# TC
# CT
# TC
# CT
# TA
# AT
# TT
# TC
# CG
# GC
# CC
# CC
# CA
# AT
# TT
# TG
# GA
# AT
# TC
# CC
# CG
# GC
# CA
# AA
# AA
# AC
# CA
# AA
# AA
# AT
# TA
# AA
# AA
# AC
# CC
# CG
# GT
# TG
# GG
# ATCCGCAAACAAATAAACCG
# GC
# CC
# CC
# CG
# GC
# CC
# CA
# AT
# TG
# GC
# CC
# CA
# AC
# CA
# AG
# GA
# AG
# GT
# TT
# TT
# TT
# TC
# CA
# AT
# TA
# AA
# AT
# TT
# TT
# TA
# AT
# TG
# GT
# TC
# CA
# AA
# AC
# CG
# GT
# TG
# GC
# CG
# GG
# TCATAATTTATGTCAACGTG
# GC
# CT
# TA
# AC
# CG
# GG
# TTTATGTCAACGTGCGGCTA
# GC
# CG
# GG
# ATGTCAACGTGCGGCTACGG
# GC
# CG
# GG
# TCAACGTGCGGCTACGGCGG
# GG
# CAACGTGCGGCTACGGCGGC
# GC
# CT
# TA
# AT
# TC
# CC
# CA
# AG
# GA
# AT
# TT
# TT
# TC
# CC
# CA
# AG
# GC
# CC
# CA
# AG
# GA
# AT
# TG
# GC
# CT
# TT
# TG
# GT
# TC
# CT
# TT
# TA
# AT
# TC
# CA
# AA
# AC
# CC
# CG
# GC
# CT
# TA
# AC
# CG
# GC
# CT
# TC
# CC
# CT
# TG
# GG
# CTTATCAACCGCTACGCTCC
# GC
# CG
# GC
# CG
# GA
# AA
# AA
# AC
# CT
# TG
# GT
# TC
# CG
# GC
# CT
# TG
# GC
# CA
# AT
# TC
# CA
# AG
# GG
# CGCGAAACTGTCGCTGCATC
# GA
# AT
# TA
# AA
# AA
# AG
# GA
# AC
# CG
# GA
# AA
# AC
# CC
# CG
# GG
# GCATCAGGATAAAGACGAAC
# GA
# AT
# TC
# CT
# TG
# GC
# CG
# GC
# CG
# GC
# CG
# GC
# CC
# CA
# AA
# AT
# TT
# TG
# GT
# TT
# TT
# TC
# CT
# TG
# GT
# TT
# TT
# TC
# CT
# TC
# CT
# TG
# GG
# GCCAATTGTTTCTGTTTCTC
# GG
# CCAATTGTTTCTGTTTCTCT
# GC
# CT
# TT
# TA
# AC
# CC
# CC
# CG
# GC
# CG
# GA
# AT
# TT
# TT
# TT
# TT
# TC
# CA
# AA
# AT
# TT
# TT
# TG
# GG
# TTACCCGCGATTTTTCAATT
# GC
# CG
# GG
# CCCGCGATTTTTCAATTTGG
# GC
# CC
# CT
# TG
# GA
# AA
# AA
# AC
# CG
# GA
# AA
# AA
# AT
# TG
# GA
# AT
# TC
# CC
# CG
# GC
# CT
# TC
# CA
# AA
# AA
# AC
# CG
# GT
# TT
# TT
# TG
# GT
# TT
# TG
# GT
# TT
# TG
# GG
# TCCGCTCAAACGTTTGTTGT
# GA
# AA
# AC
# CA
# AT
# TG
# GG
# AAACGTTTGTTGTTGGAACA
# GC
# CG
# GA
# AT
# TG
# GT
# TG
# GG
# GTTGTTGGAACATGGCGATG
# GT
# TG
# GG
# GTTGGAACATGGCGATGTGG
# GT
# TA
# AT
# TG
# GG
# AACATGGCGATGTGGTGGTA
# GG
# ACATGGCGATGTGGTGGTAT
# GG
# CATGGCGATGTGGTGGTATG
# GC
# CG
# GG
# GGCGATGTGGTGGTATGGGG
# GT
# TG
# GA
# AA
# AT
# TC
# CG
# GC
# CG
# GG
# TGGTATGGGGCGGTGAATCG
# GC
# CT
# TG
# GT
# TT
# TT
# TT
# TA
# AT
# TC
# CA
# AC
# CG
# GG
# GAATCGCGGCTGTTTTATCA
# GT
# TA
# AT
# TT
# TC
# CA
# AA
# AC
# CC
# CG
# GT
# TT
# TG
# GA
# AA
# AA
# AG
# GC
# CG
# GG
# CGGTATTCAACCGTTGAAAG
# GG
# GGTATTCAACCGTTGAAAGC
# GG
# GTATTCAACCGTTGAAAGCG
# GT
# TT
# TT
# TC
# CA
# AT
# TC
# CC
# CA
# AC
# CT
# TC
# CA
# AC
# CC
# CA
# AT
# TC
# CG
# GA
# AC
# CT
# TG
# GC
# CC
# CG
# GC
# CT
# TA
# AC
# CA
# AA
# AC
# CC
# CT
# TG
# GA
# AC
# CA
# AT
# TT
# TC
# CC
# CG
# GT
# TC
# CA
# AG
# GG
# CTACAACCTGACATTCCGTC
# GC
# CA
# AG
# GG
# AACCTGACATTCCGTCAGGC
# GT
# TA
# AA
# AA
# AA
# AA
# AA
# AG
# GA
# AA
# AT
# TA
# AA
# A
#                   target
# 0   ATTCTTTTTTACCTGCCTGA
# 1   TACCTGCCTGACGGAATGTC
# 2   GACGGAATGTCAGGTTGTAG
# 3   CAGGTTGTAGCGGCAGTCGA
# 4   TAGCGGCAGTCGATGGTGAG
# ..                   ...
# 85  CGGTATTCAACCGTTGAAAG
# 86  GGTATTCAACCGTTGAAAGC
# 87  GTATTCAACCGTTGAAAGCG
# 88  CTACAACCTGACATTCCGTC
# 89  AACCTGACATTCCGTCAGGC
#
# [90 rows x 1 columns]
